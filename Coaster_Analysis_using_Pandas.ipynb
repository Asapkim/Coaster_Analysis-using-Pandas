# %% [markdown]
# <a href="https://colab.research.google.com/github/Asapkim/Coaster_Analysis-using-Pandas/blob/main/Coaster_Analysis_using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Data Analysis using pandas

# %% [markdown]
# ## Step 0: Imports and Reading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns',200)
import zipfile
import os

# %%
zip_file=zipfile.ZipFile('archive.zip')
zip_file.extractall()
df=pd.read_csv('/content/coaster_db.csv')

# %% [markdown]
# ## Step 1:Understanding the Data
# - Dataframe `shape`
# -`head` and `tail`
# - `dtypes`
# - `describe`

# %%
df.shape
# Out:
# (1087, 56)

# %%
 df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
#df.drop(['Opened'],axis=1)

# %%
df=df[['coaster_name',
    #'Length', 'Speed',
    'Location', 'Status',
    'Opening date',
     #  'Type',
    'Manufacturer',
    #'Height restriction', 'Model', 'Height',
     #  'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
      # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
      # 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
      # 'Track layout', 'Fastrack available', 'Soft opening date.1',
      # 'Closing date',
    #'Opened',
    #'Replaced by', 'Website',
     #  'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       'Single rider line available', 'Restraint Style',
      # 'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
    'latitude', 'longitude',
    'Type_Main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph',
    #'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 16)

# %%
df.dtypes
# Out:
# coaster_name                    object
# Location                        object
# Status                          object
# Opening date                    object
# Manufacturer                    object
# Single rider line available     object
# Restraint Style                 object
# year_introduced                  int64
# latitude                       float64
# longitude                      float64
# Type_Main                       object
# opening_date_clean              object
# speed_mph                      float64
# height_ft                      float64
# Inversions_clean                 int64
# Gforce_clean                   float64
# dtype: object

# %%
df['opening_date_clean']=pd.to_datetime(df['opening_date_clean'])
df['opening_date_clean']
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %%
#Renaming columns
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Opening date', 'Manufacturer',
#        'Single rider line available', 'Restraint Style', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df=df.rename(columns={'coaster_name':'Coaster_Name',
                   'Single rider line available':'Single_Rider_Line_Available',
                   'Restraint Style':'Restraint_Style',
                    'Opening date':'Opening_Date',
                   'latitude':'Latitude',
                   'longitude':'Longitude',
                   'opening_date_clean':'Opening_Date_Clean',
                   'speed_mph':'Speed_mph',
                   'height_ft':'Height_ft',
                   'year_introduced':'Year_Introduced',
                   'Inversions_clean':'Inversions_Clean',
                   'Gforce_clean':'Gforce_Clean'}).copy()

# %%
df.isna()
# Out:
#       Coaster_Name  Location  Status  Opening_Date  Manufacturer  \
# 0            False     False   False         False         False
# 1            False     False   False         False         False
# 2            False     False   False          True          True
# 3            False     False   False         False         False
# 4            False     False   False         False         False
# ...            ...       ...     ...           ...           ...
# 1082         False     False    True          True         False
# 1083         False     False   False         False         False
# 1084         False     False    True         False         False
# 1085         False     False   False          True         False
# 1086         False     False   False         False         False
#
#       Single_Rider_Line_Available  Restraint_Style  Year_Introduced  Latitude  \
# 0                            True             True            False     False
# ...

# %%
df.isna().sum()
# Out:
# Coaster_Name                      0
# Location                          0
# Status                          213
# Opening_Date                    250
# Manufacturer                     59
# Single_Rider_Line_Available    1006
# Restraint_Style                1065
# Year_Introduced                   0
# Latitude                        275
# Longitude                       275
# Type_Main                         0
# Opening_Date_Clean              250
# Speed_mph                       150
# Height_ft                       916
# Inversions_Clean                  0
# Gforce_Clean                    725
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Opening_Date, Manufacturer, Single_Rider_Line_Available, Restraint_Style, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date_Clean, Speed_mph, Height_ft, Inversions_Clean, Gforce_Clean]
# Index: []

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])].head(5)
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Opening_Date  \
# 43                                                1926
# 60                                                1911
# 61                                        May 23, 1938
# 167                                                NaN
# 237  May 23, 1981 as Blauer Enzian, 1986 as Thunder...
#
#                                           Manufacturer  \
# 43                                  Traver Engineering
# 60                                      Fred W. Pearce
# ...

# %%
df.query('Coaster_Name=="Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status Opening_Date  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed         1926
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed         1926
#
#           Manufacturer Single_Rider_Line_Available Restraint_Style  \
# 39  Traver Engineering                         NaN             NaN
# 43  Traver Engineering                         NaN             NaN
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date_Clean  \
# 39             1926   42.8617   -79.0598      Wood         1926-01-01
# 43             1927   42.8617   -79.0598      Wood         1926-01-01
#
#     Speed_mph  Height_ft  Inversions_Clean  Gforce_Clean
# 39       60.0        NaN                 0           4.0
# 43       60.0        NaN                 0           4.0

# %%
df.duplicated(subset=['Coaster_Name','Location','Opening_Date']).sum()
# Out:
# 97

# %%
df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])]\
.reset_index(drop=True).copy()
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %% [markdown]
# # Step 3:Feature Understanding
# (Univariate analysis)
#
# - Plotting Feature Distributions
#
#      - Histogram
#
#      - KDE
#
#      - Boxplot

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    49
# 2000    47
# 1998    32
# 2011    31
# 2001    30
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
ax=df['Year_Introduced'].value_counts()\
.head(10)\
.plot(kind='bar',title='Top 10 Years Coasters were Introduced')
ax.set_xlabel('Year_Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Speed_mph'].plot(kind='hist',
                     bins=20,
                     title='Coaster Speed(mph)')
ax.set_xlabel('Speed(mph)')
ax.set_ylabel('Count')
# Out:
# Text(28.000000000000007, 0.5, 'Count')

# %%
df['Speed_mph'].plot(kind='kde',
                     title='Coaster Speed(mph)')
ax.set_xlabel('Speed(mph)')
# Out:
# Text(0.5, 28.265624999999986, 'Speed(mph)')

# %% [markdown]
# # Step 4: Feature Relationships
# (Bivariate Analysis)
#
#    - Scatterplot
#    - Heatmap Correlation
#    - Pairplot
#    - Groupby comparisons

# %%
df.plot(kind='scatter',x='Speed_mph',
        y='Height_ft',
        title='Coaster Speed vs Height')
plt.show()

# %%
sns.scatterplot(data=df,
                x='Speed_mph',
                y='Height_ft',
                hue='Year_Introduced')
plt.show()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Opening_Date', 'Manufacturer',
#        'Single_Rider_Line_Available', 'Restraint_Style', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mph',
#        'Height_ft', 'Inversions_Clean', 'Gforce_Clean'],
#       dtype='object')

# %%
sns.pairplot(df,
             vars=['Year_Introduced','Speed_mph',
                   'Height_ft','Inversions_Clean','Gforce_Clean'],
             hue='Type_Main')
plt.show()

# %%
corr_df=df[['Year_Introduced','Speed_mph',
    'Height_ft','Inversions_Clean','Inversions_Clean']].dropna().corr()
corr_df
# Out:
#                   Year_Introduced  Speed_mph  Height_ft  Inversions_Clean  \
# Year_Introduced          1.000000   0.246314   0.252420          0.109344
# Speed_mph                0.246314   1.000000   0.829404          0.159502
# Height_ft                0.252420   0.829404   1.000000          0.132756
# Inversions_Clean         0.109344   0.159502   0.132756          1.000000
# Inversions_Clean         0.109344   0.159502   0.132756          1.000000
#
#                   Inversions_Clean
# Year_Introduced           0.109344
# Speed_mph                 0.159502
# Height_ft                 0.132756
# Inversions_Clean          1.000000
# Inversions_Clean          1.000000

# %%
sns.heatmap(corr_df,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # Ask a question about the data
#   - What are the locations with the fastest roller coasters (minimum of 10)?

# %%
df['Location'].value_counts()
# Out:
# Location
# Other                                 250
# Cedar Point                            19
# Kings Island                           19
# Six Flags Magic Mountain               17
# Hersheypark                            16
#                                      ...
# New York-New York Hotel and Casino      1
# Granada Studios Tour                    1
# Funtown Splashtown USA                  1
# Suzuka, Mie Prefecture, Japan           1
# Epcot                                   1
# Name: count, Length: 280, dtype: int64

# %%
ax = df.query('Location != "Other"')\
    .groupby('Location')['Speed_mph']\
    .agg(['mean','count'])\
    .query('count>=10')\
    .sort_values('mean')['mean']\
    .plot(kind='barh',figsize=(12,5),title='Average Coast Speed by Location')
ax.set_xlabel('Average Coaster Speed(mph)')
plt.show()
